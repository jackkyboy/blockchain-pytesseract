# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rich
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import sys 
import time
import cv2

# %%
from PIL import Image
import pytesseract
from pytesseract import Output
from rich import print
from rich.panel import Panel

# %%
import pytesseract, os
from os.path import abspath
from IPython.display import Image

# %%
img = cv2.imread("/Users/apichet/Desktop/blockchain.jpg")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
thresh, img_bin = cv2.threshold(img, 230, 255, cv2.THRESH_BINARY_INV)

# %%
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)

# %%
tessdata_dir_config = '--tessdata-dir“ d:\\Tesseract-OCR\\tessdata” '

# %%
text = pytesseract.image_to_string(Image.open('/Users/apichet/Desktop/blockchain.jpg'))

# %%
Panel.fit(f"{text}", border_style="white")
# Out:
# ╭───────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                           │
# │                                                                                           │
# │ Blockchain also has potential applications far                                            │
# │ beyond bitcoin and cryptocurrency.                                                        │
# │                                                                                           │
# │ From a business perspective, it’s helpful to think of blockchain technology as a type of  │
# │ next-                                                                                     │
# │ generation business process improvement software. Collaborative technology, such as       │
# │ blockchain, promises the ability to improve the business processes that occur between     │
# ...

# %%
Image(filename='/Users/apichet/Desktop/blockchain.jpg')
